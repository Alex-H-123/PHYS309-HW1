# %% [markdown]
# # PHYS 309 Assignment 1
#
# ### Getting started
#
# <ul>
#     <li>If you do not already have the <a href="https://www.anaconda.com/products/distribution">Anaconda <tt>python</tt> distribution</a>, click the link to install the individual, free version</li>
#     <li>Download this notebook to your own computer, open with <tt>Jupyter</tt> notebook or lab, and complete the missing code. See the <a href="https://docs.jupyter.org/en/latest/start/index.html"><tt>Jupyter</tt> documentation</a> for help.</li>
# </ul>
#
# <strong>Instead of putting in the values of physical constants such as $c$ and $\epsilon_0$ by hand, use SI values pre-programmed into [scipy.constants](https://docs.scipy.org/doc/scipy/reference/constants.html).
# For example, $\mu_0$ is <tt>constants.mu_0</tt>.
#
# ### Set up <tt>python</tt> environment

# %%
import numpy as np
import matplotlib.pyplot as plt

 # Contains physical constants defined in SI units (default) as well as other systems
from scipy import constants

# Make easily readable plots with large axis labels
plt.rcParams.update({"font.size":16, "axes.labelsize":16, "font.family":"sans-serif", 
                     "font.sans-serif":"Arial"})

# %% [markdown]
# ### Questions
#
#
# Recall that the speed of light in vacuum is
# \begin{equation}
# c = \frac{1}{\sqrt{\epsilon_0 \mu_0}}, \; \; \; \; \; (1)
# \end{equation}
# where $\epsilon_0 = 8.85 \times 10^{-12}$ F/m (Farads per meter)$^{*}$ is the electric permittivity of free space and $\mu_0 = 1.26 \times 10^{-6}$ N/A$^2$ (Newtons per Ampere$^2$)$^{**}$ is the magnetic permeability of free space. The electric field created by a point charge $q$ is
# \begin{equation}
# E = \frac{1}{4 \pi \epsilon_0} \frac{q}{r^2}. \; \; \; \; (2)
# \end{equation}
#
# Suppose a charged particle is moving at some fraction $f$ of the speed of light in vacuum ($v_q = f c; \; 0 < f < 1$) as seen in reference frame $K$. Reference frame $K^{\prime}$ is co-moving with the point charge, so that $\frac{dx^{\prime}}{dt^{\prime}} = v^{\prime}_q = 0$ in frame $K^{\prime}$. To make the math easier, put $q$ at the origin of $K^{\prime}$.
#
# To understand Einstein's motivation for developing the special theory of relativity, make the <strong>incorrect, erroneous, and wrong</strong> assumption that the Galilean velocity transformation holds true for all values of $f$:
# \begin{equation}
# \frac{dx^{\prime}}{dt^{\prime}} = \frac{dx}{dt} - v_q \; \; \; (3)
# \end{equation}
#
# <ol>
#     <li>Assume the charged particle is an electron. Using Equation 2, calculate and plot the electric field as a function of distance $r^{\prime}$ from $q$ in frame $K^{\prime}$. Choose an x-axis range that makes sense to you and <strong>label both axes with correct units.</strong></li>
# </ol>

# %%
# Plot here
d = np.linspace(-2,2,200)
E = (1/(4*constants.epsilon_0*constants.pi)) * (-constants.elementary_charge/(d*d))

plt.plot(d, E)
plt.xlabel("r' (m)")
plt.ylabel("E'(r') (V/m)")
plt.title("Electric Field vs. Distance in K'", fontsize = 15)

plt.show()

# %% [markdown]
# <ol start=2>
#     <li>The Galilean velocity transformation suggests that objects can "catch up" with light, so that light in a vacuum appears to be going slower than the value of $c$ from Equation (1). Make a plot of $c^{\prime}$, the <strong>incorrect</strong> speed of light in frame $K^{\prime}$ according to the Galilean transformation, as a function of $f$. Put units on the axes where appropriate.</li>
# </ol>

# %%
# dx'/dt' = c' (speed light in K'), dx/dt = c (speed light in K), vq = fc (speed of particle/electron)
f = np.linspace(0,1,100)
speed_of_light_in_KPrime = c1 = (constants.speed_of_light) - f*(constants.speed_of_light)

plt.plot(f, c1)
plt.xlabel("f (unitless)")
plt.ylabel("c' (m/s)")
plt.title("Speed of light in frame k' as a function of f", fontsize =13)

plt.show()

# %% [markdown]
# <ol start=3>
#     <li>In frame $K^{\prime}$, something has to give: either Equation (1) is no longer true, or the values of $\epsilon_0$ and/or $\mu_0$ have to change. Suppose Equation (1) is still true and $\mu_0 = \mu_0^{\prime}$. Make a plot with two vertically stacked subplots. The top subplot should show $\epsilon_0^{\prime}$ as a function of $f$, while the bottom plot should show the electric field $E^{\prime} = \frac{1}{4 \pi \epsilon_0^{\prime}} \frac{q}{{r^{\prime}}^2}$ at $r^{\prime} = 1 \mu \mathrm{m} = 10^{-6}$ m as a function of $f$. Put units on the axes where appropriate.</li>
# </ol>

# %%
# Note: I had to use online resources to learn how to vertically stacked (not ai)
f = np.linspace(0,1,200)
y = 1 / ((constants.mu_0)*(constants.speed_of_light*(1-f))**2)
E = (1/(4*constants.pi*y)) * (-constants.elementary_charge/((1*10**(-6))**2))

fig, axs = plt.subplots(2)
fig.suptitle("Electric Field and Electric Permitivity in free space constant vs. f (relative to K')", fontsize=14)

axs[0].plot(f,y)
axs[1].plot(f,E)

axs[0].set_ylabel("Electric Permitivity in K'(F/m)",fontsize=10)
axs[1].set_ylabel("E' (V/m)", fontsize=10)
plt.xlabel("f (unitless)", fontsize=10)
# Out:
# C:\Users\alexh\AppData\Local\Temp\ipykernel_27832\2994603265.py:3: RuntimeWarning: divide by zero encountered in divide
#   y = 1 / ((constants.mu_0)*(constants.speed_of_light*(1-f))**2)
# Text(0.5, 0, 'f (unitless)')

# %% [markdown]
# <ol start=4>
#     <li>Now assume $f = 0.5$. In the same plot window, plot $E^{\prime}(r^{\prime})$ given by Equation 2 (same curve as in Problem 1) <em>and</em> $E^{\prime}(r^{\prime})$ calculated as in Problem 3, where $\epsilon_0^{\prime}$ is a function of $f$. Do you notice a problem?</li>
# </ol>

# %%
rprime = rp = np.linspace(-10,10,200)

#for the first plot I will plot E'(r') where I used f = 0.5 to calculate epsilon_0'.
epsilon0_prime_1 = e1 = 1 / (constants.mu_0*(constants.speed_of_light*(1-0.5))**2)
electric_field_plt1 = E1 = (1/(4*constants.pi*e1)) * (-constants.elementary_charge/(rp**2))
                                                
#the second plot will be of E'(r'), where epsilon_0 prime is a function of f
f = np.linspace(0,1,200)
epsilon0_prime2 = e2 = 1 / ((constants.mu_0)*(constants.speed_of_light*(1-f))**2)
electric_field_plt2 = E2 = (1/(4*constants.pi*e2)) * (-constants.elementary_charge/((rp)**2))                

#plot
plt.plot(rp,E1, label="E'(r') at f = 0.5", c = 'b')
plt.plot(rp,E2, label="E'(r') with variable f", c = 'r')
plt.title("Electric Field in K' as a function of Distance r' at variable f values", fontsize = 15)
plt.xlabel("r' (m)")
plt.ylabel("E'(r') (V/m) in K'", fontsize=10)

#legend
plt.legend(loc="lower left", fontsize = 10)
plt.show()
# Out:
# C:\Users\alexh\AppData\Local\Temp\ipykernel_27832\4169557698.py:9: RuntimeWarning: divide by zero encountered in divide
#   epsilon0_prime2 = e2 = 1 / ((constants.mu_0)*(constants.speed_of_light*(1-f))**2)

# %% [markdown]
# The problem is that the two electric fields are the same regardless of r'.

# %% [markdown]
# <ol start=5>
#     <li>To resolve the issues revealed by the plot from Problem 4, you may suggest setting $\epsilon_0^{\prime} = \epsilon_0$ and allowing $\mu_0^{\prime}$ to vary with $f$. Let's explore that solution. To accompany the point charge in problems 1-4, add a current loop that's also at rest in frame $K^{\prime}$. Recall that the magnitude of the magnetic field strength at the center of the loop in frame $K$ is $B = \frac{\mu_0 I}{2R}$, where $I$ is the current and $R$ is the radius of the loop. Suppose $I = 1$ A and $R = 1$ m. Assume $E^{\prime} = E$, $B^{\prime} = B$, and $c^{\prime}$ depends on $f$ as in problem 2. Plot $\mu_0$ as a function of $f$.</li>
# </ol>

# %%
# Plot here
f = np.linspace(0,1,200)
y = 1 / ((constants.epsilon_0)*(constants.speed_of_light*(1-f))**2)

plt.plot(f,y)
plt.title("Magnetic Permeability Constant of a Material as a function of f", fontsize = 15)
plt.xlabel("f (unitless)")
plt.ylabel("Magnetic Permeability of free spece (N/A^2)", fontsize=10)
plt.show
# Out:
# C:\Users\alexh\AppData\Local\Temp\ipykernel_27832\2257927726.py:3: RuntimeWarning: divide by zero encountered in divide
#   y = 1 / ((constants.epsilon_0)*(constants.speed_of_light*(1-f))**2)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <ol start=6>
# <li>If we calculate $c^{\prime}$ using the Galilean transformation in Equation 3, is there any value of $f$ for which $E^{\prime} = E$ <strong>and</strong> $B^{\prime} = B$? Make a graph to illustrate your answer.</li>
# </ol>

# %% [markdown]
# Answer: The only value of f where it appears that E = E' and B = B' is f = 0.
#
# At f = 0, f = 0, c' = c - fc = 0, also r' = r as r = r' + fct.
#
# To show this I graphed the electric field in K and K' at r = r' = 2. I then graphed the single point of E(r = 2) and E'(r=2, f) as a function of f. The E' curve intersected the E point when f = 0. This makes sense mathemtically because c' = c, so at f = 0 E' will have an electrical permitivity coefficient equivalent to that of the E-field in K.
#
# To show that B = B' at f = 0, I then created another plot. I plotted a single point to show the magnetic field (B) in K with arbitrary current and resistance constants. I then graphed the magnetic field (B') as a function of f. The only value when B and B' were the same was f = 0, which makes sense based on the mathematics of the Galilean transformation because at f = 0 the magnetic permeability in K and K' is the same (this is the only component of the magnetic field expression that varies as a fucntion of f).

# %%
#Note: In this code block I will demonstrate that E' = E at f = 0

rp = 2 

#x-axis/f
f = np.linspace(0,1,200)

#For E
E = [(1/(4*constants.pi*constants.epsilon_0)) * (-constants.elementary_charge/((rp)**2))]

#For E'
epsilon_0prime = e0 = 1 / ((constants.mu_0)*(constants.speed_of_light*(1-f))**2)
Ep = (1/(4*constants.pi*e0)) * (-constants.elementary_charge/((rp)**2))


#Plot
plt.plot(f,Ep, label="E'(r'=2)", c = 'b')
plt.scatter(0,E,s=100,c = 'b', label = "E(r=2)")


plt.xlabel("f (unitless)")
plt.ylabel("Electric Field (V/m)", fontsize=10)

#legend
plt.legend(loc="upper left")

plt.show()
# Out:
# C:\Users\alexh\AppData\Local\Temp\ipykernel_27832\2276170179.py:12: RuntimeWarning: divide by zero encountered in divide
#   epsilon_0prime = e0 = 1 / ((constants.mu_0)*(constants.speed_of_light*(1-f))**2)

# %%
#In this plot I will show that at f = 0, B' = B


#Constants
I = 1
R = 1

#x-axis/f
f = np.linspace(0,1,200)

#For B
B = (constants.mu_0*I)/(2*R)

#For B'
mu_0_prime = m = 1 / ((constants.epsilon_0)*(constants.speed_of_light*(1-f))**2)
Bp = (m*I)/(2*R)

#Plot
plt.plot(f,Bp, c = 'r',label="B'")
plt.scatter(0,B,s=100,c = 'b', label = "B")


plt.xlabel("f (unitless)")
plt.ylabel("Magnetic Field (T)", fontsize=10)

#legend
plt.legend(loc="upper left")

plt.show()
# Out:
# C:\Users\alexh\AppData\Local\Temp\ipykernel_27832\2206041144.py:15: RuntimeWarning: divide by zero encountered in divide
#   mu_0_prime = m = 1 / ((constants.epsilon_0)*(constants.speed_of_light*(1-f))**2)
